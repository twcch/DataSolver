# %% [markdown]
# # 股價線圖

# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
start = dt.datetime(2020, 1, 1)
end = dt.datetime(2024, 12, 31)

df_2330 = yf.download("2330.TW", start=start, end=end)
df_2454 = yf.download("2454.TW", start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fig = plt.figure(figsize=(10, 6))
plt.plot(df_2330.Close, label="TSMC")
plt.plot(df_2454.Close, label="MediaTek")
plt.title("TSMC vs MediaTek", loc="center")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(True, axis="y")
plt.legend()
plt.show()

# %% [markdown]
# # K 線圖

# %%
mpf.plot(df_2330, type="candle", title="TSMC", mav=10, volume=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(df_2330, type="line", title="TSMC", mav=10, volume=True)
