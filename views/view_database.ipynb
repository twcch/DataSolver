# %%
# %%sql
# SELECT * FROM perfect_trip_db.user_master;
# Out:
#    user_id username                          password first_name last_name  \
# 0        2     test  e10adc3949ba59abbe56e057f20f883e          王        小明
# 1        3    test1  e10adc3949ba59abbe56e057f20f883e         小紅         李
# 2        4    test3  e10adc3949ba59abbe56e057f20f883e        NaN       NaN
# 3        5    test2  e10adc3949ba59abbe56e057f20f883e        NaN       NaN
# 4        6    test8  e10adc3949ba59abbe56e057f20f883e        NaN       NaN
# 5        7    test9  e10adc3949ba59abbe56e057f20f883e        NaN       NaN
# 6        8   test10  e10adc3949ba59abbe56e057f20f883e        NaN       NaN
# 7        9   test20  e10adc3949ba59abbe56e057f20f883e        NaN       NaN
#
#   nickname     tax_id  gender user_group  phone_number country  avatar  \
# 0       小王  TAX123456    MALE     NORMAL    1234567890  Taiwan     NaN
# 1       紅紅  TAX654321  FEMALE     NORMAL  987-654-3210      台灣     NaN
# 2      NaN        NaN  FEMALE     NORMAL           NaN     NaN     NaN
# ...
